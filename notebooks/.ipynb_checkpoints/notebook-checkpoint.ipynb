# %% [markdown]
# <img src="zambia-travel.ngsversion.1503413472260.adapt.1900.1.jpg">

# %% [markdown]
# # Exploratory Analysis Green House Gas Emissions
# ## Case of Zambia
# > Data Source: World Resources Institute Climate Analysis Indicators Tool

# %%
import pandas as pd
import numpy as np
from plotly import tools
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# Here I'll load main dataset with Green House Gas emissions

# %%
df = pd.read_excel('../data/CW_CAIT_GHG_Emissions_31102017.xlsx', 
                   sheet_name='GHG Emissions')
df.columns = list(df.iloc[0].values)
df = df.drop('Country')
df_= df.reset_index()
# Out:
# /home/silas/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3108: PerformanceWarning:
#
# dropping on a non-lexsorted multi-index without a level parameter may impact performance.

# %% [markdown]
# The data contains year (1990-2014), countries, and emission contributing sectors in megatons of C0<sub>2</sub>e.  The data has some nan values in it where no data collected for the year, but otherwise clean.

# %%
df_.head(3)
# Out:
#        level_0 level_1  \
# 0  Afghanistan    1990
# 1  Afghanistan    1991
# 2  Afghanistan    1992
#
#   Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)  \
# 0                                            15.2128
# 1                                            15.2864
# 2                                            14.0105
#
#   Total GHG Emissions Including Land-Use Change and Forestry (MtCO₂e‍)  \
# 0                                            15.2128
# 1                                            15.2864
# 2                                            14.0105
#
#   Total CO2 (excluding Land-Use Change and Forestry) (MtCO2)  \
# 0                                            2.91502
# 1                                            2.68445
# 2                                            1.39227
#
#   Total CH4 (MtCO2e) Total N2O (MtCO2e) Total F-Gas (MtCO2e)  \
# 0            9.31159            2.98405           0.00218023
# 1            9.51619            3.08219           0.00361306
# 2            9.57148            3.04173           0.00504589
#
#   Total CO2 (including Land-Use Change and Forestry) (MtCO2)  \
# 0                                            2.91502
# 1                                            2.68445
# 2                                            1.39227
#
#   Total CH4 (including Land-Use Change and Forestry) (MtCO2e)  \
# 0                                            9.31159
# 1                                            9.51619
# 2                                            9.57148
#
#               ...             Industrial Processes (MtCO2e)  \
# 0             ...                                 0.0571402
# 1             ...                                 0.0585731
# 2             ...                                 0.0636699
#
#   Agriculture (MtCO2e) Waste (MtCO2e) Land-Use Change and Forestry (MtCO2)  \
# 0              7.34271        4.03895                                    0
# 1              7.63103        4.22004                                    0
# 2              7.63144        4.40112                                    0
#
#   Bunker Fuels (MtCO2) Electricity/Heat (MtCO2)  \
# 0                  NaN                      NaN
# 1                  NaN                      NaN
# 2                  NaN                      NaN
#
#   Manufacturing/Construction (MtCO2) Transportation (MtCO2)  \
# 0                                NaN                    NaN
# 1                                NaN                    NaN
# 2                                NaN                    NaN
#
#   Other Fuel Combustion (MtCO2e) Fugitive Emissions (MtCO2e)
# 0                            NaN                     1.24222
# 1                            NaN                     1.02085
# 2                            NaN                    0.602588
#
# [3 rows x 22 columns]

# %% [markdown]
# Adding the continents to the dataset for further analysis by stripping from another dataset...

# %%
# extract continents for each country in target dataset 
df3 = pd.read_csv('/home/silas/Desktop/j_zambia'+'/gapminderDataFiveYear.csv')[['country', 'continent']].drop_duplicates()
df_select = df_.rename(columns={'level_0':'country', 'level_1':'year'})
col_lst_select = ['country','year','Energy (MtCO2e)', 'Industrial Processes (MtCO2e)',
       'Agriculture (MtCO2e)', 'Waste (MtCO2e)',
       'Land-Use Change and Forestry (MtCO2)', 'Other Fuel Combustion (MtCO2e)',
       'Fugitive Emissions (MtCO2e)']

# %% [markdown]
# I want to clean up the column headers a bit for visual presentation and remove totals as we won't be needing those.

# %%
# merge continents with target dataset and clean up columns
df_all = df_select.loc[:,col_lst_select].merge(df3).set_index('continent').reset_index().rename(columns={'continent':'Continent','country':'Country','year':'Year'})
df_all.columns = list(df_all.columns.str.replace(' \(MtCO2e\)','').str.replace(' \(MtCO2\)', ''))

# %%
df_all.head(3)
# Out:
#   Continent      Country  Year   Energy Industrial Processes Agriculture  \
# 0      Asia  Afghanistan  1990  3.77404            0.0571402     7.34271
# 1      Asia  Afghanistan  1991   3.3768            0.0585731     7.63103
# 2      Asia  Afghanistan  1992   1.9143            0.0636699     7.63144
#
#      Waste Land-Use Change and Forestry Other Fuel Combustion  \
# 0  4.03895                            0                   NaN
# 1  4.22004                            0                   NaN
# 2  4.40112                            0                   NaN
#
#   Fugitive Emissions
# 0            1.24222
# 1            1.02085
# 2           0.602588

# %% [markdown]
# I'll save this merged dataset for further analysis.

# %%
# save target dataset to csv
df_all.to_csv('ghg.csv',index=False)

# %% [markdown]
# Now to drill down on GHGs related to Zambia, and comparing to its neighbors.

# %%
lst = ['Malawi', 'Zambia', 'Mozambique']
def select_countries(df,lst):
    df = df[df['Country'].isin(lst)]
    return df

# %%
df_select = select_countries(df_all,lst)
df_select_piv = df_select.pivot(index='Year', columns='Country', values= df_select.columns[3:])

# %%
fig = tools.make_subplots(rows=3, cols=1)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)

# %%
def plot_country(country):
    data = []
    for i in list(df_select_piv.columns.get_level_values(0).unique()):
        data.append(go.Bar(
        x=df_select_piv.index,
        y=df_select_piv[i][country],
        name=i
        ))

    layout = go.Layout(
        barmode='stack',
        title=country+' GHG Emissions by Sector'
    )

    fig = go.Figure(data=data, layout=layout)
    
    return fig

# %%
country='Zambia'
fig1 = plot_country(country)
iplot(fig1, filename='pandas-bar-chart-layout '+country);
# Out:
# <div id="0cb86c71-588b-42c8-9586-bfcf236ab108" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0cb86c71-588b-42c8-9586-bfcf236ab108", [{"type": "bar", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014], "y": [20.350706420075735, 20.08076644277506, 19.62082646547439, 18.840886488173727, 18.060946510873052, 17.591006533572386, 16.83798886863971, 16.974971203707035, 16.501953538774362, 15.738935873841685, 15.375918208909011, 16.159294664372414, 16.92267111983582, 17.71604757529922, 18.409424030762622, 19.262800486226023, 19.727368098278003, 19.721935710329983, 20.526503322381963, 21.21107093443394, 21.90563854648592, 22.61821449921078, 23.730790451935643, 24.2333664046605, 24.94594235738536], "name": "Energy"}, {"type": "bar", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014], "y":
}, {"type": "bar", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014], "y": [0.132052, 0.14308182455865825, 0.13945564911731653, 0.14682147367597478, 0.14685929823463306, 0.1542251227932913, 0.12877168631362135, 0.17293424983395142, 0.15114481335428145, 0.1769873768746115, 0.16252594039494156, 0.1775307279316672, 0.1412395154683928, 0.16723630300511844, 0.14560109054184406, 0.1715978780785697, 0.18298384224014055, 0.17971380640171142, 0.2057557705632823, 0.20614973472485315, 0.184559698886424, 0.19248088192300988, 0.17475406495959575, 0.25229124799618163, 0.3151724310327675], "name": "Industrial Processes"}, {"type": "bar", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014], "y": [2.1097165, 2.2188872, 2.2193712999999997, 2.2611528, 1.8454001000000002, 2.0437757, 2.1746846, 2.1612028, 2.3089104000000003, 2.2587389, 2.4015502, 2.2173982000000003, 2.4761138000000003, 2.756228, 2.7392595, 2.806016, 3.0169913999999998, 3.3243118, 3.6805077, 3.6884698, 4.2615514999999995, 4.3618975, 4.867775, 5.217634100000001, 5.239473299999999], "name": "Agriculture"}, {"type": "bar", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014], "y": [0.1607059088352582, 0.1615343073888993, 0.16236270594254038, 0.16319110449618146, 0.16401950304982255, 0.1648479016034637, 0.17064089707946412, 0.17643389255546454, 0.18222688803146497, 0.18801988350746543, 0.19381287898346589, 0.19924779400084144, 0.204682709018217, 0.2101176240355926, 0.21555253905296817, 0.22098745407034373, 0.22739291097449965, 0.23379836787865554, 0.24020382478281144, 0.24660928168696733, 0.2530147385911232, 0.2604428647715507, 0.2678709909519782, 0.2752991171324057, 0.28272724331283317], "name": "Waste"}, {"type": "bar", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014], "y": [6.6969555000000005, 6.6969555000000005, 6.6969555000000005, 6.6969555000000005, 6.6969555000000005, 6.6969555000000005, 6.8556466, 6.7697445, 6.8203483, 6.5702075, 7.008854599999999, 7.0929483, 7.2780721999999995, 8.1467201, 7.486706600000001, 7.6973194000000005, 6.350812, 6.3385264, 6.6815301, 6.2819221, 6.8195587, 4.6341581, 4.6061011, 4.3272308, 4.340414000000001], "name": "Land-Use Change and Forestry"}, {"type": "bar", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014], "y": [6.0068100000000015, 5.46280611702403, 4.918802234048059, 4.374798351072087, 3.8307944680961157, 3.286790585120144, 3.2224346338792436, 3.158078682638343, 3.0937227313974422, 3.0293667801565416, 2.965010828915641, 2.939403787435497, 2.913796 ...

# %% [markdown]
# In addition to largest contributing sectors, tt would be good to compare total emissions over time.

# %%
# get total ghgs for 3 countries
df1 = df.reset_index()
df1 = df1[df1['level_0'].isin(['Malawi', 'Zambia', 'Mozambique']) ]
df1 = pd.DataFrame(df1.iloc[:,0:3])
df1.columns = ['Country', 'year', 'Emission Totals']
df1 = df1.pivot(index='year', columns='Country', values='Emission Totals').reset_index()

# %%
df1.head()
# Out:
# Country  year   Malawi Mozambique   Zambia
# 0        1990  9.12266    18.2437  41.5585
# 1        1991  8.74378    18.1877  41.4408
# 2        1992  8.19758    18.4788  41.1258
# 3        1993   7.7916    18.8415  40.2397
# 4        1994  6.85482     18.766  39.1144

# %% [markdown]
# I'll extract population values from wb dataset in local dir.
# Then use: wget https://databank.worldbank.org/data/reports.aspx?source=2&series=SP.POP.TOTL&country=#

# %%
def merge_pop_values(lst):
    
    for i,j in enumerate(lst):
        country=i
        file = 'pop.csv'
        df_pop = pd.read_csv('/home/silas/Desktop/j_zambia/'+ file)
        vals=df_pop[df_pop['Country Name']==j]
        values_=df_pop.loc[i].values[4:]
        len_=len(values_)
        columns_=[x+1990 for x in list(range(len_))]
        df1[j+'_pop'] = values_[:25]
        
    return df1 

df_m=merge_pop_values(lst)

# %%
df_m.head()
# Out:
# Country  year   Malawi Mozambique   Zambia   Malawi_pop   Zambia_pop  \
# 0        1990  9.12266    18.2437  41.5585  8.02725e+06  1.32476e+07
# 1        1991  8.74378    18.1877  41.4408  8.23973e+06   1.3592e+07
# 2        1992  8.19758    18.4788  41.1258  8.45228e+06  1.40712e+07
# 3        1993   7.7916    18.8415  40.2397  8.66917e+06   1.4637e+07
# 4        1994  6.85482     18.766  39.1144  8.89611e+06   1.5217e+07
#
# Country Mozambique_pop Malawi_MtCO2e_pc Zambia_MtCO2e_pc Mozambique_MtCO2e_pc
# 0          9.43755e+06      1.13646e-06      3.13705e-06           1.9331e-06
# 1          9.64115e+06      1.06117e-06      3.04892e-06          1.88647e-06
# 2          9.72972e+06      9.69866e-07      2.92268e-06          1.89921e-06
# 3          9.75586e+06      8.98772e-07      2.74917e-06           1.9313e-06
# 4          9.79698e+06      7.70541e-07      2.57043e-06          1.91548e-06

# %% [markdown]
# Then calculate emissions on a total vs per capita basis.

# %%
for i in lst:
    df_m[i+'_MtCO2e_pc'] = df_m[i] / pd.to_numeric(df_m[i+'_pop'])

# %%
df_s=df_m.set_index('year').iloc[:,6:]

# %%
data = [go.Scatter(x=df_m.year, y=df_m[i], name=i) for i in list(df_m.columns)[1:4]]
layout = go.Layout(yaxis=dict(title='Total MtCO2e'), showlegend=True, title='Total GHG Emissions Excluding Land-Use Change and Forestry MtCO2e')
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='non-show-legend.html');
# Out:
# <div id="82bf4790-a586-4a56-af55-827f8ffae0db" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("82bf4790-a586-4a56-af55-827f8ffae0db", [{"type": "scatter", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014], "y": [9.12266440883526, 8.743776374839012, 8.197577740842764, 7.7916045068465145, 6.854817072850267, 6.517501938854018, 6.583651107147492, 6.564033575440969, 6.628661443734443, 6.5247222120279185, 6.536821780321393, 6.323614670042653, 6.545947359763915, 6.873950449485174, 6.849911039206436, 6.839980528927698, 7.1531921906541704, 7.496796852380642, 8.090797014107116, 8.05443537583359, 8.890969437560061, 9.076983335920092, 9.547616734280124, 10.07107993264016, 10.19690713100019], "name": "Malawi"}, {"type": "scatter", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014], "y": [18.243704333575074, 18.187740556897797, 18.47878918022052, 18.84152510354324, 18.76595422686596, 19.33895575018868, 19.411486446439795, 18.20178434269091, 20.15830983894202, 19.409390935193137, 18.534667731444248, 20.182619814203534, 19.000001096962823, 22.551308579722107, 21.573051662481394, 22.871703145240676, 21.75529281263267, 23.598740180024674, 25.258934447416674, 24.15189241480867, 26.51211098220067, 24.83666903839164, 25.529920594582617, 27.462917950773598, 28.426692806964567], "name": "Mozambique"}, {"type": "scatter", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014], "y":